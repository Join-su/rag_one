# %%
# API KEY를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %%
# !pip install -qU  gpt4all > /dev/null
# Out:
# ������ ��θ� ã�� �� �����ϴ�.

# %%
from langchain_community.embeddings import GPT4AllEmbeddings
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8344\2156821826.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.embeddings import GPT4AllEmbeddings

# %%
gpt4all_embd = GPT4AllEmbeddings()  # GPT4All 임베딩 객체를 생성합니다.
# Out:
# Downloading: 100%|██████████| 45.9M/45.9M [00:09<00:00, 4.74MiB/s]
# Verifying: 100%|██████████| 45.9M/45.9M [00:00<00:00, 545MiB/s]

# %%
text = (
    "임베딩 테스트를 하기 위한 샘플 문장입니다."  # 테스트용 문서 텍스트를 정의합니다.
)

# %%
query_result = gpt4all_embd.embed_query(
    text
)  # 주어진 텍스트에 대한 쿼리 임베딩을 생성합니다.

# %%
# 임베딩된 차원의 크기를 확인합니다.
len(query_result)
# Out:
# 384

# %%
# 주어진 텍스트를 임베딩하여 문서 벡터를 생성합니다.
doc_result = gpt4all_embd.embed_documents([text])

# %%
# 임베딩된 차원의 크기를 확인합니다.
len(doc_result[0])
# Out:
# 384
